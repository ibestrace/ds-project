# %%
import akshare as ak
import pandas as pd
import quantstats as qs

# %%
df = ak.fund_etf_fund_info_em(fund='515700')
df
# Out:
#            净值日期    单位净值    累计净值  日增长率  申购状态  赎回状态
# 0    2019-12-31  1.0003  1.0003   NaN  场内买入  场内卖出
# 1    2020-01-03  1.0148  1.0148   NaN  场内买入  场内卖出
# 2    2020-01-10  1.0575  1.0575   NaN  场内买入  场内卖出
# 3    2020-01-17  1.0778  1.0778   NaN  场内买入  场内卖出
# 4    2020-01-23  1.0907  1.0907   NaN  场内买入  场内卖出
# ..          ...     ...     ...   ...   ...   ...
# 727  2023-01-19  2.3473  2.3473  0.18  场内买入  场内卖出
# 728  2023-01-20  2.3838  2.3838  1.55  场内买入  场内卖出
# 729  2023-01-30  2.4518  2.4518  2.85  场内买入  场内卖出
# 730  2023-01-31  2.4471  2.4471 -0.19  场内买入  场内卖出
# 731  2023-02-01  2.5010  2.5010  2.20  场内买入  场内卖出
#
# [732 rows x 6 columns]

# %%
df_values = df.loc[:,['净值日期', '单位净值']]
df_values['净值日期'] = pd.to_datetime(df_values['净值日期'])
df_values.set_index(df_values['净值日期'], inplace=True)
df_values['单位净值']
# Out:
# 净值日期
# 2019-12-31    1.0003
# 2020-01-03    1.0148
# 2020-01-10    1.0575
# 2020-01-17    1.0778
# 2020-01-23    1.0907
#                ...
# 2023-01-19    2.3473
# 2023-01-20    2.3838
# 2023-01-30    2.4518
# 2023-01-31    2.4471
# 2023-02-01    2.5010
# Name: 单位净值, Length: 732, dtype: float64

# %%
qs.reports.full(df_values['单位净值'])
# Out:
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2019-12-31
# End Period                 2023-02-01
# Risk-Free Rate             0.0%
# Time in Market             100.0%
#
# Cumulative Return          150.02%
# CAGR﹪                     34.52%
#
# Sharpe                     1.01
# Prob. Sharpe Ratio         95.78%
# Smart Sharpe               0.98
# Sortino                    1.53
# Smart Sortino              1.48
# Sortino/√2                 1.08
# Smart Sortino/√2           1.05
# Omega                      1.18
#
# Max Drawdown               -45.08%
# Longest DD Days            428
# Volatility (ann.)          38.57%
# Calmar                     0.77
# Skew                       0.08
# Kurtosis                   0.66
#
# Expected Daily %           0.13%
# Expected Monthly %         2.38%
# Expected Yearly %          20.11%
# Kelly Criterion            7.95%
# Risk of Ruin               0.0%
# ...

# %%
qs.reports.html(df_values['单位净值'])
# Out:
# C:\Users\ThinkPad\.conda\envs\qtconda\lib\site-packages\quantstats\stats.py:968: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   returns = returns.pivot('Year', 'Month', 'Returns').fillna(0)
# C:\Users\ThinkPad\.conda\envs\qtconda\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# ...
